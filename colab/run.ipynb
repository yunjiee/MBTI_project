  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 424.6083416938782
#
# Iteration:  94% 153/162 [01:38<00:05,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 427.3856463432312
#
# Iteration:  95% 154/162 [01:39<00:05,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 430.16553020477295
#
# Iteration:  96% 155/162 [01:40<00:04,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 432.9267132282257
#
# Iteration:  96% 156/162 [01:40<00:03,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 435.6975350379944
#
# Iteration:  97% 157/162 [01:41<00:03,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 438.4897651672363
#
# Iteration:  98% 158/162 [01:42<00:02,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 441.25277376174927
#
# Iteration:  98% 159/162 [01:42<00:01,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 444.0258309841156
#
# Iteration:  99% 160/162 [01:43<00:01,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 446.7956235408783
#
# Iteration:  99% 161/162 [01:44<00:00,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 449.5796391963959
#
# Iteration: 100% 162/162 [01:44<00:00,  1.55it/s]
# Saving checkpoint for epoch 59 at /content/drive/My Drive/full/output/checkpoint_epoch_59.pt
# Checkpoint saved successfully
# Deleted checkpoint: /content/drive/My Drive/full/output/checkpoint_epoch_53.pt
# Error deleting checkpoint /content/drive/My Drive/full/output/checkpoint_epoch_53.pt: [Errno 2] No such file or directory: 'trash-empty'
# 第59週期 訓練完成
#  41% 60/145 [1:47:03<2:33:29, 108.35s/it]開始訓練 第60週期
#
# Iteration:   0% 0/162 [00:00<?, ?it/s]tr_loss是整个训练周期（epoch）内的总损失 2.7827394008636475
#
# Iteration:   1% 1/162 [00:00<01:42,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 5.57347297668457
#
# Iteration:   1% 2/162 [00:01<01:42,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 8.342029571533203
#
# Iteration:   2% 3/162 [00:01<01:40,  1.58it/s]tr_loss是整个训练周期（epoch）内的总损失 11.139461517333984
#
# Iteration:   2% 4/162 [00:02<01:40,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 13.90307331085205
#
# Iteration:   3% 5/162 [00:03<01:39,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 16.682188987731934
#
# Iteration:   4% 6/162 [00:03<01:39,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 19.444412231445312
#
# Iteration:   4% 7/162 [00:04<01:38,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 22.21657657623291
#
# Iteration:   5% 8/162 [00:05<01:38,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 24.979395866394043
#
# Iteration:   6% 9/162 [00:05<01:37,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 27.755985975265503
#
# Iteration:   6% 10/162 [00:06<01:36,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 30.53207802772522
#
# Iteration:   7% 11/162 [00:07<01:36,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 33.299973011016846
#
# Iteration:   7% 12/162 [00:07<01:35,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 36.07930612564087
#
# Iteration:   8% 13/162 [00:08<01:35,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 38.84640336036682
#
# Iteration:   9% 14/162 [00:08<01:34,  1.57it/s]tr_loss是整个训练周期（epoch）内的总损失 41.627859592437744
#
# Iteration:   9% 15/162 [00:09<01:34,  1.56it/s]tr_loss是整个训练周期（epoch）内的总损失 44.392927169799805
#
# Iteration:  10% 16/162 [00:10<01:33,  1.56it/s]tr_loss是整个训练周期（epoch）内的总损失 47.1738703250885
#
# Iteration:  10% 17/162 [00:10<01:32,  1.56it/s]tr_loss是整个训练周期（epoch）内的总损失 49.95001816749573
#
# Iteration:  11% 18/162 [00:11<01:32,  1.56it/s]tr_loss是整个训练周期（epoch）内的总损失 52.722535610198975
#
# Iteration:  12% 19/162 [00:12<01:31,  1.56it/s]tr_loss是整个训练周期（epoch）内的总损失 55.51067519187927
#
# Iteration:  12% 20/162 [00:12<01:31,  1.56it/s]tr_loss是整个训练周期（epoch）内的总损失 58.28533887863159
#
# Iteration:  13% 21/162 [00:13<01:30,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 61.05514740943909
#
# Iteration:  14% 22/162 [00:14<01:30,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 63.85604906082153
#
# Iteration:  14% 23/162 [00:14<01:29,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 66.6417305469513
#
# Iteration:  15% 24/162 [00:15<01:29,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 69.40490818023682
#
# Iteration:  15% 25/162 [00:16<01:28,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 72.18616700172424
#
# Iteration:  16% 26/162 [00:16<01:28,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 74.96188926696777
#
# Iteration:  17% 27/162 [00:17<01:27,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 77.73628449440002
#
# Iteration:  17% 28/162 [00:17<01:27,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 80.51524829864502
#
# Iteration:  18% 29/162 [00:18<01:26,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 83.27331805229187
#
# Iteration:  19% 30/162 [00:19<01:26,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 86.0500123500824
#
# Iteration:  19% 31/162 [00:19<01:25,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 88.82446670532227
#
# Iteration:  20% 32/162 [00:20<01:25,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 91.6210126876831
#
# Iteration:  20% 33/162 [00:21<01:24,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 94.39583683013916
#
# Iteration:  21% 34/162 [00:21<01:23,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 97.17206764221191
#
# Iteration:  22% 35/162 [00:22<01:23,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 99.95546746253967
#
# Iteration:  22% 36/162 [00:23<01:22,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 102.73522567749023
#
# Iteration:  23% 37/162 [00:23<01:22,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 105.52112054824829
#
# Iteration:  23% 38/162 [00:24<01:21,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 108.294673204422
#
# Iteration:  24% 39/162 [00:25<01:20,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 111.07651901245117
#
# Iteration:  25% 40/162 [00:25<01:20,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 113.85892271995544
#
# Iteration:  25% 41/162 [00:26<01:19,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 116.63493347167969
#
# Iteration:  26% 42/162 [00:27<01:19,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 119.39880967140198
#
# Iteration:  27% 43/162 [00:27<01:18,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 122.17334794998169
#
# Iteration:  27% 44/162 [00:28<01:18,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 124.94068026542664
#
# Iteration:  28% 45/162 [00:29<01:17,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 127.71314549446106
#
# Iteration:  28% 46/162 [00:29<01:16,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 130.50211358070374
#
# Iteration:  29% 47/162 [00:30<01:16,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 133.28916335105896
#
# Iteration:  30% 48/162 [00:31<01:15,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 136.0575077533722
#
# Iteration:  30% 49/162 [00:31<01:14,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 138.83691358566284
#
# Iteration:  31% 50/162 [00:32<01:13,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 141.62221813201904
#
# Iteration:  31% 51/162 [00:33<01:13,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 144.41098833084106
#
# Iteration:  32% 52/162 [00:33<01:12,  1.51it/s]tr_loss是整个训练周期（epoch）内的总损失 147.17812752723694
#
# Iteration:  33% 53/162 [00:34<01:11,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 149.94688248634338
#
# Iteration:  33% 54/162 [00:35<01:11,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 152.73224759101868
#
# Iteration:  34% 55/162 [00:35<01:10,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 155.49732398986816
#
# Iteration:  35% 56/162 [00:36<01:09,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 158.27018404006958
#
# Iteration:  35% 57/162 [00:37<01:08,  1.52it/s]tr_loss是整个训练周期（epoch）内的总损失 161.03823113441467
#
# Iteration:  36% 58/162 [00:37<01:08,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 163.80191159248352
#
# Iteration:  36% 59/162 [00:38<01:07,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 166.57874488830566
#
# Iteration:  37% 60/162 [00:39<01:06,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 169.35049057006836
#
# Iteration:  38% 61/162 [00:39<01:05,  1.53it/s]tr_loss是整个训练周期（epoch）内的总损失 172.1357982158661
#
# Iteration:  38% 62/162 [00:40<01:05,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 174.90950465202332
#
# Iteration:  39% 63/162 [00:40<01:04,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 177.67740893363953
#
# Iteration:  40% 64/162 [00:41<01:03,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 180.46342539787292
#
# Iteration:  40% 65/162 [00:42<01:03,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 183.23922443389893
#
# Iteration:  41% 66/162 [00:42<01:02,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 186.01505327224731
#
# Iteration:  41% 67/162 [00:43<01:01,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 188.79785180091858
#
# Iteration:  42% 68/162 [00:44<01:01,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 191.57981252670288
#
# Iteration:  43% 69/162 [00:44<01:00,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 194.3679792881012
#
# Iteration:  43% 70/162 [00:45<00:59,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 197.14643359184265
#
# Iteration:  44% 71/162 [00:46<00:58,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 199.9115583896637
#
# Iteration:  44% 72/162 [00:46<00:58,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 202.69430017471313
#
# Iteration:  45% 73/162 [00:47<00:57,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失 205.47792887687683
#
# Iteration:  46% 74/162 [00:48<00:57,  1.54it/s]tr_loss是整个训练周期（epoch）内的总损失
  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 299.56323409080505
#
# Iteration:  67% 108/162 [01:09<00:34,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 302.3283517360687
#
# Iteration:  67% 109/162 [01:10<00:34,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 305.0939185619354
#
# Iteration:  68% 110/162 [01:11<00:33,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 307.87109303474426
#
# Iteration:  69% 111/162 [01:11<00:32,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 310.635550737381
#
# Iteration:  69% 112/162 [01:12<00:32,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 313.3975188732147
#
# Iteration:  70% 113/162 [01:13<00:31,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 316.18032145500183
#
# Iteration:  70% 114/162 [01:13<00:31,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 318.9588372707367
#
# Iteration:  71% 115/162 [01:14<00:30,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 321.71895360946655
#
# Iteration:  72% 116/162 [01:14<00:29,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 324.4890639781952
#
# Iteration:  72% 117/162 [01:15<00:29,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 327.25826930999756
#
# Iteration:  73% 118/162 [01:16<00:28,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 330.02243399620056
#
# Iteration:  73% 119/162 [01:16<00:27,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 332.8148317337036
#
# Iteration:  74% 120/162 [01:17<00:27,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 335.59285616874695
#
# Iteration:  75% 121/162 [01:18<00:26,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 338.36937069892883
#
# Iteration:  75% 122/162 [01:18<00:25,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 341.12649607658386
#
# Iteration:  76% 123/162 [01:19<00:25,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 343.88740134239197
#
# Iteration:  77% 124/162 [01:20<00:24,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 346.67856001853943
#
# Iteration:  77% 125/162 [01:20<00:23,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 349.4682819843292
#
# Iteration:  78% 126/162 [01:21<00:23,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 352.24203085899353
#
# Iteration:  78% 127/162 [01:22<00:22,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 355.00767493247986
#
# Iteration:  79% 128/162 [01:22<00:21,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 357.76605892181396
#
# Iteration:  80% 129/162 [01:23<00:21,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 360.5448772907257
#
# Iteration:  80% 130/162 [01:24<00:20,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 363.32704758644104
#
# Iteration:  81% 131/162 [01:24<00:19,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 366.0824112892151
#
# Iteration:  81% 132/162 [01:25<00:19,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 368.84472393989563
#
# Iteration:  82% 133/162 [01:25<00:18,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 371.64445662498474
#
# Iteration:  83% 134/162 [01:26<00:18,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 374.44365906715393
#
# Iteration:  83% 135/162 [01:27<00:17,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 377.2076327800751
#
# Iteration:  84% 136/162 [01:27<00:16,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 379.9820730686188
#
# Iteration:  85% 137/162 [01:28<00:16,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 382.7584698200226
#
# Iteration:  85% 138/162 [01:29<00:15,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 385.5511083602905
#
# Iteration:  86% 139/162 [01:29<00:14,  1.55it/s]tr_loss是整个训练周期（epoch）内的总损失 388.32941031455994
#
# Iteration:  86% 140/162 [01:30<00:14,  1.55it/s]

# %% [markdown]
# 修改.py檔案

# %%
# %%writefile '/content/drive/My Drive/full/fine_tune_save_colab.py'
# from __future__ import absolute_import, division, print_function
#
# #用於确保代码在不同版本的Python中具有一致的行为(维护同时需要在Python 2和Python 3环境下运行的代码非常有用)
# #!pip install pytorch-pretrained-bert
#
# import argparse #解析命令行参数 =>运行程序时从命令行指定这些参数
# import subprocess
# import os
# import random
# import glob
# import numpy as np
# import torch
# import csv
#
# from torch.utils.data import (DataLoader, RandomSampler, SequentialSampler,TensorDataset)
# from torch.utils.data.distributed import DistributedSampler
# from tqdm import tqdm, trange
#
# from torch.nn import CrossEntropyLoss, MSELoss
# #pip install scipy
# from scipy.stats import pearsonr, spearmanr
# #pip install scikit-learn
# from sklearn.metrics import matthews_corrcoef, f1_score
#
# #from transformers import BertTokenizer, BertForSequenceClassification, AdamW
# from transformers import BertTokenizer, BertForSequenceClassification
# from torch.optim import AdamW
#
# #from pytorch_pretrained_bert.file_utils import PYTORCH_PRETRAINED_BERT_CACHE, WEIGHTS_NAME, CONFIG_NAME
# #from pytorch_pretrained_bert.modeling import BertForSequenceClassification, BertConfig
# #from pytorch_pretrained_bert.tokenization import BertTokenizer
# #from pytorch_pretrained_bert.optimization import BertAdam, WarmupLinearSchedule
#
# from compute_metrics import compute_metrics
# #from data_processor import InputExample, DataProcessor, PersonalityProcessor
# from processor import InputExample, DataProcessor, PersonalityProcessor
# from features import convert_examples_to_features
# from dataloader import get_train_dataloader, get_eval_dataloader, get_label_ids
# from bert_model import get_bert_model, get_optimizer
#
#
# loss_csv_file = '/content/drive/My Drive/full/output/loss_file.csv'
# def find_latest_checkpoints(output_dir, num_to_keep=2):
#     checkpoint_files = glob.glob(os.path.join(output_dir, 'checkpoint_epoch_*.pt'))
#     checkpoints = [(os.path.basename(path), int(os.path.basename(path).split('_')[-1].split('.')[0])) for path in checkpoint_files]
#     checkpoints = sorted(checkpoints, key=lambda x: x[1], reverse=True)
#     return checkpoints[:num_to_keep]
#
# def remove_old_checkpoints(output_dir, checkpoints_to_keep):
#     all_checkpoints = set(glob.glob(os.path.join(output_dir, 'checkpoint_epoch_*.pt')))
#     checkpoints_to_keep = set(os.path.join(output_dir, cp[0]) for cp in checkpoints_to_keep)
#     for checkpoint in all_checkpoints - checkpoints_to_keep:
#         try:
#             os.remove(checkpoint)
#             print(f"Deleted checkpoint: {checkpoint}")
#             subprocess.run(["trash-empty"], check=True)
#         except Exception as e:
#             print(f"Error deleting checkpoint {checkpoint}: {e}")
#
# #在开始训练的循环之前，检查是否有现有的检查点并加载它。
# def load_checkpoint(model, optimizer, path):
#     if os.path.isfile(path):
#         print("加载检查点'{}'".format(path))
#         #checkpoint = torch.load(path)
#         checkpoint = torch.load(path, map_location=torch.device("cpu") if not torch.cuda.is_available() else None)
#         model.load_state_dict(checkpoint['state_dict'])
#         optimizer.load_state_dict(checkpoint['optimizer'])
#
#         if not os.path.isfile(loss_csv_file):
#             with open(loss_csv_file, mode='w', newline='') as file:
#                 writer = csv.writer(file)
#                 writer.writerow(['Epoch', 'Average Loss'])
#         return checkpoint['epoch']
#     else:
#         print("没有找到检查点 '{}'".format(path))
#         # 创建新的训练损失记录文件
#         with open(loss_csv_file, mode='w', newline='') as file:
#             writer = csv.writer(file)
#             writer.writerow(['Epoch', 'Average Loss'])
#         return 0
#
# def main():
#     #### 創建一個解析器，用於處理命令行參數 ####
#     ###################### 参数解析 (argparse)，可以靈活的取用外部參數 ######################
#
#     parser = argparse.ArgumentParser()
#     #### 添加各種命令行參數 ####
#     #调用定义了一个命令行参数的规则，包括如何解析该参数以及该参数的一些元数据
#     #参数名称以两个连字符（--）开头，它被视为一个可选参数(是那些在命令行中可以省略的参数。意味着在命令行中使用这些参数时，需要使用其完整的名称)
#     #--沒修改，默认为 "./"（当前目录）
#     parser.add_argument("--data_dir", default="/content/drive/My Drive/full/data/", type=str)#數據目錄
#     ##data_dire資料夾內要有: train.csv 用于训练，dev.csv 或 eval.csv 用于模型评估
#     parser.add_argument("--bert_model", default="bert-base-uncased", type=str)#使用的bert模型
#     parser.add_argument("--output_dir", default="/content/drive/My Drive/full/output/", type=str)#輸出目錄
#     #output_dir資料夾: 训练过程中生成的模型和输出数据将保存在这个目录中
#
#     parser.add_argument("--cache_dir", default="", type=str)#緩存目錄
#     parser.add_argument("--max_seq_length", default=128, type=int)#最大序列長度
#
#     parser.add_argument("--do_train", action='store_true', default=True)#是否經過訓練
#     #, default=True 代表不管有沒有do_train，都默認有，並執行程式
#     parser.add_argument("--do_eval", action='store_true', default=True)#是否進行評估
#     parser.add_argument("--do_lower_case", action='store_true')#是否將文本轉為小寫
#
#     parser.add_argument("--train_batch_size", default=32, type=int)
#     parser.add_argument("--eval_batch_size", default=8, type=int)#評估時的批次大小
#     parser.add_argument("--learning_rate", default=5e-5, type=float)#學習率
#
#     parser.add_argument("--num_train_epochs", default=145, type=int) #執行的次數
#     parser.add_argument("--warmup_proportion", default=0.1, type=float)
#
#     parser.add_argument("--local_rank", type=int, default=-1)
#     parser.add_argument('--seed', type=int, default=42)
#     parser.add_argument('--gradient_accumulation_steps', type=int, default=1)
#
#     parser.add_argument('--mode', default="ALL", type=str)
#     #用于解析命令行参数(将每个参数与之前通过 add_argument 定义的参数进行匹配，并基于提供的信息对这些参数进行适当的类型转换)
#     #如果命令行参数不符合预定义的规则，parse_args()会自动显示错误信息并退出程序
#     #这在创建需要用户输入参数的脚本时非常有用。
#
#     parser.add_argument("--weight_decay", default=0.01, type=float)
#     parser.add_argument("--adam_epsilon", default=1e-8, type=float)
#
#     #### 解析从命令行传递给 Python 脚本的参数 ####
#     #用于使 Python 程序能够更容易地从命令行接受参数。这对于创建可配置的脚本或应用程序非常有用，因为你可以在不修改代码的情况下改变程序的行为。
#
#     args = parser.parse_args()
#
#     ##################### 設定設備(cpu或gpu) #####################
#     if torch.cuda.is_available():
#         device = torch.device("cuda")
#         print('使用GPU')
#     else:
#         device = torch.device("cpu")
#         print('使用CPU')
#
#
#     ####################### 梯度累积步骤设置: #####################
#     if args.gradient_accumulation_steps < 1:
#         raise ValueError("Invalid gradient_accumulation_steps parameter: {}, should be >= 1".format(args.gradient_accumulation_steps))
#     args.train_batch_size = args.train_batch_size // args.gradient_accumulation_steps
#     ### 目的: 为了优化模型的训练过程，使其适应不同的硬件配置 ###
#     ### 随机数生成的操作（如数据分割、初始化模型权重等）将产生相同的结果 ###
#     random.seed(args.seed)
#     np.random.seed(args.seed)
#     torch.manual_seed(args.seed)
#
#     #检查训练和评估标志：这部分代码确保至少进行训练(do_train)或评估(do_eval)中的一个
#     if not args.do_train and not args.do_eval:
#         raise ValueError("At least one of `do_train` or `do_eval` must be True.")
#     ## 检查输出目录是否存在，如果不存在，则创建它
#     if not os.path.exists(args.output_dir):
#         os.makedirs(args.output_dir)
#         print(f"输出目录 {args.output_dir} 不存在，已创建。")
#
#
#     #代码使用 PersonalityProcessor 来处理数据，获取训练样本和标签列表。这些标签用于模型训练过程中的分类任务。
#     processor = PersonalityProcessor(args.mode)
#     label_list = processor.get_labels(args.data_dir)
#
#     print("label_list               ",label_list)
#     num_labels = len(label_list)
#
#     #创建一个BERT分词器（Tokenizer），它用于将文本数据转换成BERT模型能够理解的格式。
#     tokenizer = BertTokenizer.from_pretrained(args.bert_model, do_lower_case=args.do_lower_case)
#     #args.bert_model 是一个命令行参数，它表示BERT模型的名称或路径
#
#     train_examples = processor.get_train_examples(args.data_dir)
#     if not train_examples:
#         raise ValueError("No training examples returned by the processor.")
#
#     num_train_optimization_steps = None
#     if args.do_train:
#         num_train_optimization_steps = int(
#             len(train_examples) / args.train_batch_size / args.gradient_accumulation_steps) * args.num_train_epochs
#         if args.local_rank != -1:
#             num_train_optimization_steps = num_train_optimization_steps // torch.distributed.get_world_size()
#
#     #### Prepare model
#     model = BertForSequenceClassification.from_pretrained(args.bert_model, num_labels=num_labels)
#     model.to(device)
#
#     #### Prepare optimizer
#     optimizer = get_optimizer(args, model, num_train_optimization_steps)
#
#     def save_checkpoint(model, optimizer, epoch, path, loss_history):
#         try:
#             print("Saving checkpoint for epoch", epoch, "at", path)
#             state = {
#                 'epoch': epoch,
#                 'state_dict': model.state_dict(),
#                 'optimizer': optimizer.state_dict(),
#                 'loss_history': loss_history  # 添加 loss_history 到状态字典
#             }
#             torch.save(state, path)
#             print("Checkpoint saved successfully")
#         except Exception as e:
#             print("Error saving checkpoint:", e)
#     # 在开始训练之前加载检查点
#     global_step = 0
#
#     latest_checkpoints = find_latest_checkpoints(args.output_dir)
#     if latest_checkpoints:
#         latest_checkpoint_path = os.path.join(args.output_dir, latest_checkpoints[0][0])
#         start_epoch = load_checkpoint(model, optimizer, latest_checkpoint_path)
#
#         print('继续训练从 epoch', start_epoch, '开始')
#     else:
#         start_epoch = 0
#         print("没有找到检查点，将从头开始训练。")
#
#     ### 模型訓練 ###
#     if args.do_train:
#         ##### 準備使用的訓練數據 ####
#         #convert_examples_to_features：将文本数据转换为模型可接受的格式
#         train_features = convert_examples_to_features(train_examples, label_list, args.max_seq_length, tokenizer)
#         #train_examples來自Processor
#         train_dataloader = get_train_dataloader(args, train_features)
#
#         #深度学习模型的训练循环
#         #保存模型，将训练后的模型及其配置保存到文件中
#         #int(args.num_train_epochs)
#         #for epoch in trange(args.num_train_epochs):
#         loss_history = []
#         for epoch in trange(start_epoch,args.num_train_epochs):
#             print("開始訓練 第{}週期".format(epoch))
#             tr_loss = 0 #訓練週期的損失
#             ### 準備評估數據 ###
#             nb_tr_examples, nb_tr_steps = 0, 0
#             model.train()
#
#             #分別記錄處理的樣本數和步驟數
#             for step, batch in enumerate(tqdm(train_dataloader, desc="Iteration")):
#                 batch = tuple(t.to(device) for t in batch)
#                 input_ids, input_mask, segment_ids, label_ids = batch
#
#                 # define a new function to compute loss values for both output_modes
#                 #通过模型传递输入数据，获取 logits（模型的原始输出）。
#                 output = model(input_ids, segment_ids, input_mask, labels=None)
#                 logits = output.logits
#
#                 #计算预测和真实标签之间的损失
#                 loss_fct = CrossEntropyLoss()
#                 #loss= 模型的预测与真实标签之间的差异
#                 loss = loss_fct(logits.view(-1, num_labels), label_ids.view(-1))
#
#                 #通过对损失进行平均化，您可以减小梯度计算的方差，从而更稳定地训练模型
#                 loss = loss.mean()
#                 if args.gradient_accumulation_steps > 1:
#                     #有限的 GPU 内存下有助于使用更大的批次大小。
#                     loss = loss / args.gradient_accumulation_steps
#
#                 loss.backward() #反向传播以计算梯度
#
#                 #tr_loss 随着每个训练周期逐渐减少，表明模型正在学习并提高其预测的准确性。(是整个训练周期（epoch）内的总损失)
#                 tr_loss += loss.item()
#                 print("tr_loss是整个训练周期（epoch）内的总损失",tr_loss)
#                  # 计算每个训练周期的平均损失
#                 nb_tr_examples += input_ids.size(0)
#                 nb_tr_steps += 1
#
#                 if (step + 1) % args.gradient_accumulation_steps == 0:
#                     optimizer.step() #更新模型參數
#                     optimizer.zero_grad() #清除梯度信息，为下一个批次做准备
#                     global_step += 1
#                 ## 计算整个周期的平均损失
#                 avg_loss = tr_loss / nb_tr_steps if nb_tr_steps != 0 else 0
#                 loss_history.append(avg_loss)
#             # 在每个周期结束后存储该周期的平均损失
#             if (epoch + 1) % 1 == 0:  # 在每个周期结束后存储，这里的 1 表示每个周期结束后都存储
#                 # 写入每个周期的平均损失到 CSV 文件
#                 with open(loss_csv_file, mode='a', newline='') as file:
#                     writer = csv.writer(file)
#                     writer.writerow([epoch, avg_loss])
#
#             # 每三个epoch保存一次检查点
#             if (epoch + 1) % 3 == 0:
#                 checkpoint_path = os.path.join(args.output_dir, f'checkpoint_epoch_{epoch}.pt')
#                 save_checkpoint(model, optimizer, epoch, checkpoint_path, loss_history)
#                 # 检查并保留最新的两个检查点，删除旧的
#                 latest_checkpoints = find_latest_checkpoints(args.output_dir)
#                 remove_old_checkpoints(args.output_dir, latest_checkpoints)
#             print("第{}週期 訓練完成".format(epoch))
#
#         final_checkpoint_path = os.path.join(args.output_dir, f'checkpoint_epoch_{epoch}.pt')
#         save_checkpoint(model, optimizer, start_epoch + 1, final_checkpoint_path, loss_history)
#         # 检查并保留最新的两个检查点，删除旧的
#         latest_checkpoints = find_latest_checkpoints(args.output_dir)
#         remove_old_checkpoints(args.output_dir, latest_checkpoints)
#
#     ####### 如果成功執行，它会将训练过程中得到的模型和相关配置保存到指定的目录中，並可以重新使用這數據 #######
#     #如果不是在分布式训练环境中（local_rank == -1），或者如果是在分布式训练环境中的主进程（torch.distributed.get_rank() == 0），那么执行后续的代码块（比如保存模型）
#     if args.do_train and (args.local_rank == -1 or torch.distributed.get_rank() == 0):
#         #条件检查是否完成了训练，并且在分布式训练环境中只在主节点（rank 0）上执行保存操作
#         # Save a trained model, configuration and tokenizer
#         #提取实际的模型以供保存
#         model_to_save = model.module if hasattr(model, 'module') else model  # Only save the model it-self
#         print("ˊ執行到 args.do_train ######################################")
#
#         # 在此处定义模型权重文件的名称
#         output_model_file = os.path.join(args.output_dir, "pytorch_model.bin")
#         output_config_file = os.path.join(args.output_dir, "config.json")
#         #
#         #保存模型的状态字典（state_dict），这包含了模型的所有权重和偏差参数。
#         torch.save(model_to_save.state_dict(), output_model_file)
#         model_to_save.config.to_json_file(output_config_file) #将模型的配置保存为 JSON 文件
#         # 保存分词器的词汇表
#         tokenizer.save_vocabulary(args.output_dir) #用于模型的分词器保存到指定目录。
#
#         #从保存的文件中加载训练后的模型和分词器。
#         model = BertForSequenceClassification.from_pretrained(args.bert_model, num_labels=num_labels)
#         tokenizer = BertTokenizer.from_pretrained(args.output_dir, do_lower_case=args.do_lower_case)
#     else:
#         #如果没有进行训练，则直接从预训练的 BERT 模型加载。
#         print("沒有進行訓練到，则直接从预训练的 BERT 模型加载            ")
#         model = BertForSequenceClassification.from_pretrained(args.bert_model, num_labels=num_labels)
#     #将模型移动到指定的设备（比如 GPU），來進行訓練評估
#     model.to(device)
#
#     #評估
#     if args.do_eval and (args.local_rank == -1 or torch.distributed.get_rank() == 0):
#         #準備評估數據
#         #指定的数据目录加载开发集（或验证集）
#         eval_examples = processor.get_dev_examples(args.data_dir)
#         eval_features = convert_examples_to_features(eval_examples, label_list, args.max_seq_length, tokenizer)
#         eval_dataloader = get_eval_dataloader(args, eval_features)
#         all_label_ids = get_label_ids(args, eval_features)
#         print("eval_examples               ",eval_examples)
#
#         model.eval()
#         eval_loss = 0
#         nb_eval_steps = 0
#         preds = []
#
#         for input_ids, input_mask, segment_ids, label_ids in tqdm(eval_dataloader, desc="Evaluating"):
#             input_ids = input_ids.to(device)
#             input_mask = input_mask.to(device)
#             segment_ids = segment_ids.to(device)
#             label_ids = label_ids.to(device)
#
#             with torch.no_grad():
#                 #logits = model(input_ids, segment_ids, input_mask, labels=None)
#                 outputs = model(input_ids, attention_mask=input_mask, token_type_ids=segment_ids)
#                 logits = outputs.logits
#
#             # create eval loss and other metric required by the task
#             loss_fct = CrossEntropyLoss()
#             tmp_eval_loss = loss_fct(logits.view(-1, num_labels), label_ids.view(-1))
#             print("tmp_eval_loss             ",tmp_eval_loss)
#
#             eval_loss += tmp_eval_loss.mean().item()
#             nb_eval_steps += 1
#             if len(preds) == 0:
#                 preds.append(logits.detach().cpu().numpy())
#             else:
#                 preds[0] = np.append(
#                     preds[0], logits.detach().cpu().numpy(), axis=0)
#         print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
#         eval_loss = eval_loss / nb_eval_steps
#
#         preds = preds[0]
#         preds = np.argmax(preds, axis=1)
#
#         result = compute_metrics(preds, all_label_ids.numpy(), label_list)
#         loss = tr_loss/global_step if args.do_train else None
#
#         result['eval_loss'] = eval_loss
#         result['global_step'] = global_step
#         result['loss'] = loss
#         #print(result)
#         ##輸出結果
#         output_eval_file = os.path.join(args.output_dir, "eval_results.txt")
#         with open(output_eval_file, "w") as writer:
#             for key in result.keys():
#                 writer.write("%s = %s\n" % (key, str(result[key])))
#
# if __name__ == "__main__":
#     main()
#     # 在训练完成后绘制损失历史图表
# Out:
# Overwriting /content/drive/My Drive/full/fine_tune_save_colab.py
